# %%
# %run pia-u2-tarea1.py
# Out:
# Access Key: ASIAYI3VDGRBXXBVZ4EG
# Secret Key length: 40
# Conexión correcta. Listando buckets:
# {'ResponseMetadata': {'RequestId': 'ADR826RW73NXH5PB', 'HostId': 'D8oNiDqw4j4YNdq+LDklMsj5ipSs4KX42atYKrZPPPvLuRLP0qyIA1hY6QkynbXJuMvP89kM53p7Pt6xIR4vuZM/XTbnu8d5', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'D8oNiDqw4j4YNdq+LDklMsj5ipSs4KX42atYKrZPPPvLuRLP0qyIA1hY6QkynbXJuMvP89kM53p7Pt6xIR4vuZM/XTbnu8d5', 'x-amz-request-id': 'ADR826RW73NXH5PB', 'date': 'Fri, 14 Nov 2025 11:47:39 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'Buckets': [{'Name': 'pia-bucket', 'CreationDate': datetime.datetime(2025, 11, 14, 8, 37, 38, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::pia-bucket'}], 'Owner': {'ID': 'ce241e8edd449a19ba4f8ac3fa2a75c97cf1d172ec68d9ce3bfc4682faac8a05'}}
# ...
